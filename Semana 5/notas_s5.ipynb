# %%
numeros = (10,20,30,40,50,60,70)
print(numeros[0])
print(numeros[2])
print(numeros[4])
print(numeros[-1])

# %%
Coordenadas = (10, 20)  # define la tupla antes de desempacarla
x, y = Coordenadas

print(f"Coordenada en x: {x}")
print(f"Coordenada en y: {y}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 x,y = Coordenadas
#       2
#       3 print(f"Coordenada en x: {x}")
#       4 print(f"Coordenada en y: {y}")
#
# NameError: name 'Coordenadas' is not defined

# %%
calificaciones = (88,90,100,85)

calif5= 50
calif6=80

nuevas_calificaciones = calificaciones + (calif5,calif6)

print(calificaciones)
print(nuevas_calificaciones)
# Out:
# (88, 90, 100, 85)
# (88, 90, 100, 85, 50, 80)

# %%
desordenada = (9, 2, 7, 10, 0, 8, 14, 22, 4)

print(type(desordenada))
print(desordenada)
lista=list(desordenada)
print()
print(type(lista))
print(lista)
print()
lista.sort()
print(lista)
ordenada=tuple(lista)
print()
print(type(ordenada))
print(ordenada)
# Out:
# <class 'tuple'>
# (9, 2, 7, 10, 0, 8, 14, 22, 4)
#
# <class 'list'>
# [9, 2, 7, 10, 0, 8, 14, 22, 4]
#
# [0, 2, 4, 7, 8, 9, 10, 14, 22]
#
# <class 'tuple'>
# (0, 2, 4, 7, 8, 9, 10, 14, 22)

# %%
def suma_tupla(t):
    total = 0
    for e in t:
        total += e
    return total

calorias = (800, 950, 700, 1300, 800, 900, 650)
resultado = suma_tupla(calorias)
print(f"Metiste a tu cuerpo {resultado} calorías, gordo!")
# Out:
# Metiste a tu cuerpo 6100 calorías, gordo!

# %%
contactos = {
    "Richard":4455962144,
    "Peter":7789654432,
    "Loise":55412388956

}

print(type(contactos))
print(len(contactos))
print(contactos["Peter"])
# Out:
# <class 'dict'>
# 3
# 7789654432

# %%
contactos = {
    "Richard":4455962144,
    "Peter":7789654432,
    "Loise":55412388956
}

contactos["Chris"] = 8855522699
contactos["Richard"] = 4455566322
print(contactos)
# Out:
# {'Richard': 4455566322, 'Peter': 7789654432, 'Loise': 55412388956, 'Chris': 8855522699}

# %%
ladrones = {
    "Shaudia Cleinbaum": 0,
    "Gochitl Xalvez": 0,
    "El Otro": 0   
}
cant = int(input("¿Cuántos votos serán?"))
conteo = 1

while conteo >= cant:
    votoxvoto=input("Ingrese su voto {c} (Shaudia, Gochitl, Otro: ")
    print(f"Voto por {votoxvoto.upper()}")
    if votoxvoto.upper() in ladrones:
        print(f"Voto para {votoxvoto.upper()}")
        ladrones[votoxvoto.upper()] 
    else:
        print("El voto no es válido")

for k, v in ladrones.items():
    print(f"Opción {k}, votos: {v}")
# Out:
# Opción Shaudia Cleinbaum, votos: 0
# Opción Gochitl Xalvez, votos: 0
# Opción El Otro, votos: 0
